# %%
import pandas as pd

df1 = pd.read_csv('HRDataset_v14.csv')
df2 = pd.read_csv('Airbnb_Dataset_19.csv')

# %%
df1
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  EmpStatusID  \
# 0    Ait Sidi, Karthikeyan     10084          1                1            5
# 1           Akinkuolie, Sarah  10196          1                1            5
# 2            Anderson, Carol   10069          0                2            5
# 3        Baczenski, Rachael    10252          1                1            5
# 4             Barbara, Thomas  10242          1                1            5
# ..                        ...    ...        ...              ...          ...
# 99              Wilber, Barry  10048          1                1            5
# 100             Wilkes, Annie  10204          0                2            5
# 101     Williams, Jacquelyn    10264          0                0            5
# 102        Winthrop, Jordan    10033          0                0            5
# 103        Ybarra, Catherine   10301          0                0            5
#
# ...

# %%
df2
# Out:
#         Id                                              Name  Host_Id  \
# 0     2539                Clean & quiet apt home by the park     2787
# 1     2595                             Skylit Midtown Castle     2845
# 2     3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3     3831                   Cozy Entire Floor of Brownstone     4869
# 4     5022  Entire Apt: Spacious Studio/Loft by central park     7192
# ..     ...                                               ...      ...
# 244  61492          Exclusive Room with Private Bath in  LES   297769
# 245  61509               Quiet, clean midtown apt w. elevato    23619
# 246  62095                 BK Sweet Suite w/Kitchen&FullBath   281764
# 247  62427               Great East Village Apartment Rental   303882
# 248  62430                     BROWNSTONE SUNDRENCHED BEAUTY   197755
#
#         Host_Name Neighbourhood_Group  Neighbourhood  Latitude  Longitude  \
# ...

# %%
print(df1.isnull().sum())
# Out:
# Employee_Name                 0
# EmpID                         0
# MarriedID                     0
# MaritalStatusID               0
# EmpStatusID                   0
# DeptID                        0
# PerfScoreID                   0
# FromDiversityJobFairID        0
# Salary                        0
# Termd                         0
# PositionID                    0
# Position                      0
# State                         0
# Zip                           0
# DOB                           0
# Sex                           0
# MaritalDesc                   0
# CitizenDesc                   0
# HispanicLatino                0
# RaceDesc                      0
# DateofHire                    0
# DateofTermination             0
# TermReason                    0
# EmploymentStatus              0
# Department                    0
# ManagerName                   0
# ManagerID                     0
# RecruitmentSource             0
# PerformanceScore              0
# ...

# %%
print(df2.isnull().sum())
# Out:
# Id                                0
# Name                              0
# Host_Id                           0
# Host_Name                         0
# Neighbourhood_Group               0
# Neighbourhood                     0
# Latitude                          0
# Longitude                         0
# Room_Type                         0
# Price                             0
# Minimum_Nights                    0
# Number_Of_Reviews                 0
# Last_Review                       7
# Reviews_Per_Month                 7
# Calculated_Host_Listings_Count    0
# Availability_365                  0
# dtype: int64

# %%
# inpute missing values
df1.fillna(df.mean(), inplace=True)

# drop rows with missing values
df1.dropna(inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6412\978605918.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.fillna(df.mean(), inplace=True)

# %%
print(df1.duplicated().sum())

# drop duplicates
df1.drop_duplicates(inplace=True)
# Out:
# 0

# %%
print(df2.duplicated().sum())

# drop duplicates
df2.drop_duplicates(inplace=True)
# Out:
# 0

# %%
df1
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  EmpStatusID  \
# 0    Ait Sidi, Karthikeyan     10084          1                1            5
# 1           Akinkuolie, Sarah  10196          1                1            5
# 2            Anderson, Carol   10069          0                2            5
# 3        Baczenski, Rachael    10252          1                1            5
# 4             Barbara, Thomas  10242          1                1            5
# ..                        ...    ...        ...              ...          ...
# 99              Wilber, Barry  10048          1                1            5
# 100             Wilkes, Annie  10204          0                2            5
# 101     Williams, Jacquelyn    10264          0                0            5
# 102        Winthrop, Jordan    10033          0                0            5
# 103        Ybarra, Catherine   10301          0                0            5
#
# ...

# %%
df2
# Out:
#         Id                                              Name  Host_Id  \
# 0     2539                Clean & quiet apt home by the park     2787
# 1     2595                             Skylit Midtown Castle     2845
# 2     3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3     3831                   Cozy Entire Floor of Brownstone     4869
# 4     5022  Entire Apt: Spacious Studio/Loft by central park     7192
# ..     ...                                               ...      ...
# 244  61492          Exclusive Room with Private Bath in  LES   297769
# 245  61509               Quiet, clean midtown apt w. elevato    23619
# 246  62095                 BK Sweet Suite w/Kitchen&FullBath   281764
# 247  62427               Great East Village Apartment Rental   303882
# 248  62430                     BROWNSTONE SUNDRENCHED BEAUTY   197755
#
#         Host_Name Neighbourhood_Group  Neighbourhood  Latitude  Longitude  \
# ...

# %%
# identify outliers
df1.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID  EmpStatusID      DeptID  \
# count    104.000000  104.000000       104.000000   104.000000  104.000000
# mean   10167.701923    0.451923         0.942308     4.788462    4.711538
# std       89.400146    0.500093         0.943315     0.633576    0.920881
# min    10004.000000    0.000000         0.000000     1.000000    1.000000
# 25%    10090.750000    0.000000         0.000000     5.000000    5.000000
# 50%    10170.500000    0.000000         1.000000     5.000000    5.000000
# 75%    10249.750000    1.000000         1.000000     5.000000    5.000000
# max    10305.000000    1.000000         4.000000     5.000000    6.000000
#
#        PerfScoreID  FromDiversityJobFairID  Termd  PositionID           Zip  \
# count   104.000000              104.000000  104.0  104.000000    104.000000
# mean      2.903846                0.153846    1.0   18.134615   3244.894231
# ...

# %%
# identify outliers
df2.describe()
# Out:
#                  Id       Host_Id    Latitude   Longitude  Minimum_Nights  \
# count    249.000000  2.490000e+02  249.000000  249.000000      249.000000
# mean   31376.771084  1.499884e+05   40.730257  -73.964044        8.718876
# std    18101.018309  4.010393e+05    0.049660    0.029685       20.398680
# min     2539.000000  2.787000e+03   40.631880  -74.080880        1.000000
# 25%    15711.000000  5.014800e+04   40.688430  -73.984980        2.000000
# 50%    28321.000000  9.779700e+04   40.721620  -73.964280        3.000000
# 75%    46911.000000  1.936370e+05   40.761930  -73.948220        5.000000
# max    62430.000000  6.197784e+06   40.867540  -73.765970      200.000000
#
#        Number_Of_Reviews  Reviews_Per_Month  Calculated_Host_Listings_Count  \
# count         249.000000         242.000000                      249.000000
# mean          103.445783           1.091653                        1.738956
# ...

# %%
df1
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  EmpStatusID  \
# 0    Ait Sidi, Karthikeyan     10084          1                1            5
# 1           Akinkuolie, Sarah  10196          1                1            5
# 2            Anderson, Carol   10069          0                2            5
# 3        Baczenski, Rachael    10252          1                1            5
# 4             Barbara, Thomas  10242          1                1            5
# ..                        ...    ...        ...              ...          ...
# 99              Wilber, Barry  10048          1                1            5
# 100             Wilkes, Annie  10204          0                2            5
# 101     Williams, Jacquelyn    10264          0                0            5
# 102        Winthrop, Jordan    10033          0                0            5
# 103        Ybarra, Catherine   10301          0                0            5
#
# ...

# %%
df1.hist(column = "EmpID",figsize=(9,6),bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'EmpID'}>]], dtype=object)

# %%
df1["EmpSatisfaction"].plot(kind="box",figsize=(9,9))
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.boxplot(df1['PerfScoreID'])
plt.xlabel('PerfScoreID')
plt.title('Box plot of PerfScoreID')
plt.show()

# %%
import seaborn as sns
sns.heatmap(df1.corr(), annot=True, cmap='coolwarm')
plt.title('Heatmap of the correlation matrix')
plt.show()

# %%
plt.plot(df['EmpID'], df1['EngagementSurvey'])
plt.xlabel('EmpID')
plt.ylabel('EngagementSurvey')
plt.title('Line plot of EngagementSurvey')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df1['EmpID'], df1['MaritalStatusID'])
plt.xlabel('EmpID')
plt.ylabel('MaritalStatusID')
plt.title('Scatter plot between EmpID and MaritalStatusID')
plt.show()

# %%
plt.plot(df2['Host_Id'], df2['Latitude'])
plt.xlabel('Host_Id')
plt.ylabel('Latitude')
plt.title('Line plot of Latitude')
plt.show()

# %%
import matplotlib.pyplot as plt
plt.scatter(df2['Id'], df2['Latitude'])
plt.xlabel('Id')
plt.ylabel('Latitude')
plt.title('Scatter plot between EmpID and Latitude')
plt.show()

# %%
sns.pairplot(df1)
plt.title('Scatter plot matrix of df1')
plt.show()

# %%
sns.violinplot(x='EngagementSurvey', y='dataset', data=pd.concat([df1.assign(dataset='df1'), df2.assign(dataset='df2')]), hue='dataset')
plt.xlabel('EngagementSurvey')
plt.ylabel('Dataset')
plt.title('Violin plot of EngagementSurvey in df1 and df2')
plt.show()
